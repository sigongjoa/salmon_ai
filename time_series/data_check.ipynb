# %% [markdown]
# *  KU-MWQ A Dataset for Monitoring Water Quality Using Digital Sensors
# > https://data.mendeley.com/datasets/34rczh25kc/4
#
# * Sensor Based Aquaponics Fish Pond Datasets
# > https://www.kaggle.com/datasets/e81da8b7666dc7af41cdc3aa5ef96c5547e4f412598a030f40d444550965e34f
#
# * fish-weight-prediction
# > https://www.kaggle.com/code/ybifoundation/fish-weight-prediction
#
# * Feeding and growth dataset of Gilthead Seabream (Sparus aurata) fed with local shellfish in diets of juvenile
# > https://entrepot.recherche.data.gouv.fr/dataset.xhtml?persistentId=doi:10.57745/FPSH2TFeeding%20and%20growth%20dataset%20of%20Gilthead%20Seabream%20(Sparus%20aurata)%20fed%20with%20local%20shellfish%20in%20diets%20of%20juvenile
#
# * Data from: High summer macrophyte cover increases abundance, growth and feeding of juvenile Atlantic salmon
# > https://datadryad.org/stash/dataset/doi:10.5061/dryad.612jm643t

# %%
import os
import pandas as pd

# %%
fish = pd.read_csv('https://github.com/ybifoundation/Dataset/raw/main/Fish.csv')

# %%
fish
# Out:
#      Category Species  Weight   Height   Width  Length1  Length2  Length3
# 0           1   Bream   242.0  11.5200  4.0200     23.2     25.4     30.0
# 1           1   Bream   290.0  12.4800  4.3056     24.0     26.3     31.2
# 2           1   Bream   340.0  12.3778  4.6961     23.9     26.5     31.1
# 3           1   Bream   363.0  12.7300  4.4555     26.3     29.0     33.5
# 4           1   Bream   430.0  12.4440  5.1340     26.5     29.0     34.0
# ..        ...     ...     ...      ...     ...      ...      ...      ...
# 154         6   Smelt    12.2   2.0904  1.3936     11.5     12.2     13.4
# 155         6   Smelt    13.4   2.4300  1.2690     11.7     12.4     13.5
# 156         6   Smelt    12.2   2.2770  1.2558     12.1     13.0     13.8
# 157         6   Smelt    19.7   2.8728  2.0672     13.2     14.3     15.2
# 158         6   Smelt    19.9   2.9322  1.8792     13.8     15.0     16.2
#
# [159 rows x 8 columns]

# %%
from ftplib import FTP
import os

def download_from_ftp(host, path, local_path='.'):
    with FTP(host) as ftp:
        ftp.login()  # If authentication is required, provide username and password here.
        ftp.cwd(path)
        filenames = ftp.nlst()  # List of filenames in the current directory
        
        if not os.path.exists(local_path):
            os.makedirs(local_path)

        for filename in filenames:
            with open(os.path.join(local_path, filename), 'wb') as local_file:
                ftp.retrbinary('RETR ' + filename, local_file.write)

# Usage
download_from_ftp('ftp.nefsc.noaa.gov', '/pub/dropoff/PARR/READ/PSB/NEST/27493/', 'local_directory_path')
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# <ipython-input-9-440018c15864> in <module>
#      16
#      17 # Usage
# ---> 18 download_from_ftp('ftp.nefsc.noaa.gov', '/pub/dropoff/PARR/READ/PSB/NEST/27493/', 'local_directory_path')
#
# <ipython-input-9-440018c15864> in download_from_ftp(host, path, local_path)
#       3
#       4 def download_from_ftp(host, path, local_path='.'):
# ----> 5     with FTP(host) as ftp:
#       6         ftp.login()  # If authentication is required, provide username and password here.
#       7         ftp.cwd(path)
#
# /usr/lib/python3.8/ftplib.py in __init__(self, host, user, passwd, acct, timeout, source_address)
#     117         self.timeout = timeout
#     118         if host:
# --> 119             self.connect(host)
#     120             if user:
#     121                 self.login(user, passwd, acct)
#
# /usr/lib/python3.8/ftplib.py in connect(self, host, port, timeout, source_address)
#     152             self.source_address = source_address
#     153         sys.audit("ftplib.connect", self, self.host, self.port)
# --> 154         self.sock = socket.create_connection((self.host, self.port), self.timeout,
#     155                                              source_address=self.source_address)
#     156         self.af = self.sock.family
#
# /usr/lib/python3.8/socket.py in create_connection(address, timeout, source_address)
#     806     if err is not None:
#     807         try:
# --> 808             raise err
#     809         finally:
#     810             # Break explicitly a reference cycle
#
# /usr/lib/python3.8/socket.py in create_connection(address, timeout, source_address)
#     794             if source_address:
#     795                 sock.bind(source_address)
# --> 796             sock.connect(sa)
#     797             # Break explicitly a reference cycle
#     798             err = None
#
# TimeoutError: [Errno 110] Connection timed out
